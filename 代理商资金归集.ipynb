# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import sqlite3

# %%
df = pd.read_csv('../data/zjgj3.txt')

# %%
df.tail(500)
# Out:
#          ﻿TransDate Province City MerNumber                          MerName  \
# 3421686    20160922       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# 3421687    20160921       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# 3421688    20160921       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# 3421689    20160921       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# 3421690    20160921       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# 3421691    20160921       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# 3421692    20160921       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# 3421693    20160921       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# 3421694    20160921       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# 3421695    20160921       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# 3421696    20160921       辽宁   沈阳   91b1f7c  网上商城皇姑区沈阳都尔通信服务有限公司怒江北街合作营业厅代办点
# ...
